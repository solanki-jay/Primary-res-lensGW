# %%
pip install lalsuite pycbc lenstronomy

# %%
# !git clone https://username:pass@github.com/SSingh087/test.git
# Out:
# Cloning into 'test'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (213/213), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 213 (delta 82), reused 118 (delta 25), pack-reused 0
# Receiving objects: 100% (213/213), 1.47 MiB | 1.64 MiB/s, done.
# Resolving deltas: 100% (82/82), done.

# %%
cd test
# Out:
# /content/test

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating lensGW.egg-info
# writing lensGW.egg-info/PKG-INFO
# writing dependency_links to lensGW.egg-info/dependency_links.txt
# writing requirements to lensGW.egg-info/requires.txt
# writing top-level names to lensGW.egg-info/top_level.txt
# writing manifest file 'lensGW.egg-info/SOURCES.txt'
# writing manifest file 'lensGW.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/lensGW
# copying lensGW/__init__.py -> build/lib/lensGW
# creating build/lib/lensGW/waveform
# copying lensGW/waveform/waveform.py -> build/lib/lensGW/waveform
# copying lensGW/waveform/__init__.py -> build/lib/lensGW/waveform
# copying lensGW/waveform/waveform_utils.py -> build/lib/lensGW/waveform
# creating build/lib/lensGW/amplification_factor
# ...

# %%
cd ..
# Out:
# /content

# %%
# !git clone https://username:pass@github.com/SSingh087/lensGW-PyCBC-plugin.git
# Out:
# Cloning into 'lensGW-PyCBC-plugin'...
# remote: Enumerating objects: 230, done.
# remote: Counting objects: 100% (230/230), done.
# remote: Compressing objects: 100% (159/159), done.
# remote: Total 230 (delta 100), reused 133 (delta 43), pack-reused 0
# Receiving objects: 100% (230/230), 93.02 KiB | 294.00 KiB/s, done.
# Resolving deltas: 100% (100/100), done.

# %%
cd lensGW-PyCBC-plugin
# Out:
# /content/lensGW-PyCBC-plugin

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing pycbc_lensGW.egg-info/PKG-INFO
# writing dependency_links to pycbc_lensGW.egg-info/dependency_links.txt
# writing entry points to pycbc_lensGW.egg-info/entry_points.txt
# writing requirements to pycbc_lensGW.egg-info/requires.txt
# writing top-level names to pycbc_lensGW.egg-info/top_level.txt
# writing manifest file 'pycbc_lensGW.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# copying build/lib/lgw.py -> build/bdist.linux-x86_64/egg
# byte-compiling build/bdist.linux-x86_64/egg/lgw.py to lgw.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying pycbc_lensGW.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pycbc_lensGW.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# ...

# %%
from lgw import *
from pycbc import waveform
import pylab
if __name__ == "__main__":
    waveform.add_custom_waveform('lensed', lensed_gw_td, 'time', force=True)
    hp_tilde_lensed, hc_tilde_lensed = waveform.get_td_waveform(
                    approximant="lensed",
                    y0 = 0.1,y1 = 0.7937005,l0 = 0.5,l1 = 0,zS = 2.0,zL = 0.5,mL=[1e3,1e3], lens_model_list = ['POINT_MASS', 'POINT_MASS'],
                    approx='IMRPhenomD',mass1=500,mass2=500,spin1x=0.0,spin1y=0.0,
                    spin1z=0.3,spin2x=0.0,spin2y=0.0,spin2z=0.4,inclination=1.23,
                    distance=1000,coa_phase=2.45,delta_t=1.0/16384,delta_f=16384,f_lower=20,
                    eccentricity=.3)
    pylab.figure(figsize=(18,8))
    pylab.xticks(fontsize=18)
    pylab.yticks(fontsize=18)
    pylab.xlabel('Sample times',fontsize=18)
    pylab.plot(hp_tilde_lensed.sample_times, hp_tilde_lensed,label='h$_+$')
    pylab.plot(hp_tilde_lensed.sample_times, hc_tilde_lensed,label='h$_x$')
    pylab.legend(loc=0,fontsize=18)
    pylab.grid()
# Out:
# /usr/local/lib/python3.6/dist-packages/lensGW-1.0.0-py3.6.egg/lensGW/utils/utils.py:17: ComplexWarning: Casting complex values to real discards the imaginary part
